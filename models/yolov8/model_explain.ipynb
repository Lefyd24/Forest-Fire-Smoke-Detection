# %%
import torch
from ultralytics import YOLO

# %%
model = YOLO("weights/best.pt")

# %%
results = model.track("https://www.youtube.com/watch?v=xjdQBbOlBl8&ab_channel=OPEN", show=True)
# Out:
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# ...
#   Obtaining dependency information for lapx>=0.5.2 from https://files.pythonhosted.org/packages/0e/80/8c28ea4c3f61c8f0742ae6fcd7046cd06afb436778575aea6da3f03793ac/lapx-0.5.4-cp310-cp310-macosx_10_9_universal2.whl.metadata
# ...
#   Obtaining dependency information for Cython>=0.29.32 from https://files.pythonhosted.org/packages/f6/94/8d553dff3baf9cdd4b2481e59c2cfc8247c0c847170dd10574f81718d142/Cython-3.0.0-py2.py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 1.6 MB/s eta 0:00:0000:0100:010m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 5.0 MB/s eta 0:00:00a 0:00:01
# ...
#
# requirements: AutoUpdate success ✅ 3.7s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# requirements: Ultralytics requirements ['pafy', 'youtube_dl==2020.12.2'] not found, attempting AutoUpdate...
# ...
