# %%
import cv2
import torch
from ultralytics import YOLO
import os
from ultralytics.utils.plotting import Annotator

# %%
def detect_fire_smoke(model_path1, input_path, output_path, model_path2=None):
    # Load the models
    model1 = YOLO(model_path1)
    if model_path2:
        model2 = YOLO(model_path2)

    # Define colors for bounding boxes for each model
    color_model1 = (0, 255, 0)  # Green for model1
    color_model2 = (0, 0, 255)  # Red for model2

    def draw_boxes(annotator, results, model, color):
        for r in results:
            boxes = r.boxes
            for box in boxes:
                b = box.xyxy[0]  # get box coordinates in (top, left, bottom, right) format
                c = box.cls
                label = f"{model.names[int(c)]} {box.conf.item():.2f}"  # Add confidence to the label
                annotator.box_label(b, label, color=color)

    # Check if the input is an image or a video
    if input_path.endswith('.jpg') or input_path.endswith('.png') or input_path.endswith('.jpeg'):
        # Handle image
        img = cv2.imread(input_path)
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # Predict with both models
        results1 = model1.predict(img, conf=0.2)
        annotator = Annotator(img)

        draw_boxes(annotator, results1, model1, color_model1)

        if model_path2:
            results2 = model2.predict(img, conf=0.2)
            draw_boxes(annotator, results2, model2, color_model2)

        img = annotator.result()

        # Save the result
        cv2.imwrite(output_path, img)

    else:
        # Handle video
        cap = cv2.VideoCapture(input_path)

        # Get video frame size
        frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

        # Define the codec and create a VideoWriter object
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        out = cv2.VideoWriter(output_path, fourcc, 20.0, (frame_width, frame_height))

        while cap.isOpened():
            ret, frame = cap.read()

            if ret:  # if frame read successfully
                img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

                # Predict with both models
                results1 = model1.predict(img, conf=0.2)
                annotator = Annotator(frame)

                draw_boxes(annotator, results1, model1, color_model1)

                if model_path2:
                    results2 = model2.predict(img, conf=0.2)
                    draw_boxes(annotator, results2, model2, color_model2)

                frame = annotator.result()

                # write the flipped frame
                out.write(frame)
            else:  # if frame not read successfully, then we reached the end of the video
                break

        # Release everything when job is finished
        cap.release()
        out.release()
        cv2.destroyAllWindows()

# %%
model_path1 = "/Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/models/model_chris/weights/best.pt"
model_path2 = 'models/model_chris_0908/weights/best.pt'
input_ = "test_files/rodos_maris.mp4"
output_ = "runs_pret/out_comparison_4_Rodos_Maris.mp4"

# %%
detect_fire_smoke(model_path1, input_, output_, model_path2)
# Out:
# 0: 384x640 1 Smoke, 131.2ms
# Speed: 5.8ms preprocess, 131.2ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 smoke, 207.2ms
# Speed: 2.2ms preprocess, 207.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Smoke, 119.3ms
# Speed: 1.7ms preprocess, 119.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 smoke, 264.3ms
# Speed: 1.4ms preprocess, 264.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Smokes, 127.0ms
# Speed: 1.7ms preprocess, 127.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 smoke, 258.6ms
# Speed: 1.3ms preprocess, 258.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Smoke, 84.9ms
# Speed: 1.5ms preprocess, 84.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 smoke, 179.2ms
# Speed: 1.3ms preprocess, 179.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Smoke, 119.9ms
# Speed: 2.2ms preprocess, 119.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 smoke, 206.6ms
# Speed: 1.3ms preprocess, 206.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Smoke, 104.6ms
# Speed: 1.3ms preprocess, 104.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 smoke, 188.8ms
# Speed: 1.6ms preprocess, 188.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Smoke, 89.7ms
# Speed: 1.4ms preprocess, 89.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 smoke, 184.7ms
# Speed: 1.5ms preprocess, 184.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Smoke, 99.6ms
# Speed: 1.6ms preprocess, 99.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 smoke, 185.6ms
# Speed: 1.2ms preprocess, 185.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Smoke, 78.3ms
# Speed: 1.4ms preprocess, 78.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 smoke, 166.1ms
# Speed: 1.3ms preprocess, 166.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Smoke, 77.9ms
# Speed: 1.3ms preprocess, 77.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 smoke, 166.4ms
# Speed: 1.5ms preprocess, 166.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Smoke,
6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 270.7ms
# Speed: 2.5ms preprocess, 270.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Smokes, 162.8ms
# Speed: 2.8ms preprocess, 162.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 smoke, 291.1ms
# Speed: 8.7ms preprocess, 291.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Smoke, 137.9ms
# Speed: 2.7ms preprocess, 137.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 1 smoke, 277.4ms
# Speed: 2.7ms preprocess, 277.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Smoke, 136.7ms
# Speed: 2.6ms preprocess, 136.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 279.1ms
# Speed: 3.2ms preprocess, 279.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Smokes, 160.4ms
# Speed: 2.4ms preprocess, 160.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 1 smoke, 276.9ms
# Speed: 11.8ms preprocess, 276.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Smokes, 138.1ms
# Speed: 2.9ms preprocess, 138.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 1 smoke, 284.1ms
# Speed: 2.5ms preprocess, 284.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Smokes, 138.9ms
# Speed: 2.7ms preprocess, 138.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 320.9ms
# Speed: 3.2ms preprocess, 320.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Smokes, 149.9ms
# Speed: 2.8ms preprocess, 149.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 1 smoke, 278.1ms
# Speed: 2.5ms preprocess, 278.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Smokes, 136.0ms
# Speed: 2.5ms preprocess, 136.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 1 smoke, 273.1ms
# Speed: 2.5ms preprocess, 273.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Smokes, 138.2ms
# Speed: 2.6ms preprocess, 138.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 307.9ms
# Speed: 2.6ms preprocess, 307.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Smoke, 138.9ms
# Speed: 2.7ms preprocess, 138.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 smoke, 272.9ms
# Speed: 2.5ms preprocess, 272.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Smokes, 138.8ms
# Speed: 2.8ms preprocess, 138.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 smoke, 289.5ms
# Speed: 2.6ms preprocess, 289.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Smokes, 133.4ms
# Speed: 2.7ms preprocess, 133.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 smoke, 281.7ms
# Speed: 2.6ms preprocess, 281.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Smokes, 135.5ms
# Speed: 3.4ms preprocess, 135.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 smoke, 274.5ms
# Speed: 2.6ms preprocess, 274.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Smoke, 139.9ms
# Speed: 2.8ms preprocess, 139.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 321.6ms
# Speed: 2.7ms preprocess, 321.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Smoke, 155.3ms
# Speed: 3.5ms preprocess, 155.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 274.3ms
# Speed: 2.5ms preprocess, 274.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Smokes, 135.7ms
# Speed: 2.6ms preprocess, 135.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 smoke, 297.2ms
# Speed: 2.6ms preprocess, 297.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Smoke, 139.5ms
# Speed: 2.8ms preprocess, 139.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 330.4ms
# Speed: 2.6ms preprocess, 330.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Smokes, 146.2ms
# Speed: 2.6ms preprocess, 146.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 277.1ms
# Speed: 2.6ms preprocess, 277.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)

# %%
import os

for idx, file in enumerate(os.listdir("test_files")):
    if idx > 60 and idx < 120: 
        if file.endswith(".png") or file.endswith(".jpg") or file.endswith(".jpeg"):
            input_path = os.path.join("test_files", file)
            output_path = os.path.join("runs_comparison", file)
            try:
                detect_fire_smoke(model_path1, input_path, output_path, model_path2)
            except:
                print("Error with file: ", file)
                continue
        else:
            continue
    elif idx <= 60:
        continue
    else:
        break
# Out:
# 0: 416x640 1 Fire, 1 Smoke, 89.7ms
# Speed: 2.5ms preprocess, 89.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 fires, 177.3ms
# Speed: 1.5ms preprocess, 177.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 320x640 3 Fires, 68.5ms
# Speed: 1.2ms preprocess, 68.5ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 fires, 180.3ms
# Speed: 1.2ms preprocess, 180.3ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 352x640 1 Fire, 74.0ms
# Speed: 1.4ms preprocess, 74.0ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 fire, 150.6ms
# Speed: 1.3ms preprocess, 150.6ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 448x640 1 Fire, 1 Smoke, 95.7ms
# Speed: 1.4ms preprocess, 95.7ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 fire, 2 smokes, 193.3ms
# Speed: 1.3ms preprocess, 193.3ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 416x640 (no detections), 105.3ms
# Speed: 1.4ms preprocess, 105.3ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 smoke, 179.8ms
# Speed: 1.2ms preprocess, 179.8ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 448x640 2 Fires, 1 Smoke, 89.4ms
# Speed: 1.5ms preprocess, 89.4ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 fire, 190.4ms
# Speed: 1.6ms preprocess, 190.4ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 2 Smokes, 77.2ms
# Speed: 1.4ms preprocess, 77.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 smokes, 161.7ms
# Speed: 1.3ms preprocess, 161.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 3 Fires, 108.8ms
# Speed: 1.5ms preprocess, 108.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 fires, 213.7ms
# Speed: 1.7ms preprocess, 213.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 Fire, 81.2ms
# Speed: 1.3ms preprocess, 81.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 171.7ms
# Speed: 1.4ms preprocess, 171.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Fires, 83.3ms
# Speed: 1.2ms preprocess, 83.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fires, 166.8ms
# Speed: 1.3ms preprocess, 166.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 2 Fires, 98.5ms
# Speed: 1.4ms preprocess, 98.5ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 5 fires, 201.5ms
# Speed: 1.3ms preprocess, 201.5ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x608 2 Fires, 139.1ms
# Speed: 1.7ms preprocess, 139.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x608 3 fires, 259.4ms
# Speed: 1.9ms preprocess, 259.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 448x640 2 Fires, 98.1ms
# Speed: 1.4ms preprocess, 98.1ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 fires, 204.2ms
# Speed: 1.6ms preprocess, 204.2ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 2 Fires, 84.1ms
# Speed: 1.5ms preprocess, 84.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 177.9ms
# Speed: 1.3ms preprocess, 177.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 Smoke, 104.8ms
# Speed: 1.6ms preprocess, 104.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 smokes, 204.2ms
# Speed: 1.5ms preprocess, 204.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 (no detections), 84.7ms
# Speed: 1.2ms preprocess, 84.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 169.0ms
# Speed: 1.2ms preprocess, 169.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 3 Fires, 1 Smoke, 99.1ms
# Speed: 1.4ms preprocess, 99.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fire, 1 smoke, 235.2ms
# Speed: 1.3ms preprocess, 235.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 Fire, 104.0ms
# Speed: 1.5ms preprocess, 104.0ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 fire, 195.9ms
# Speed: 1.4ms preprocess, 195.9ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 416x640 2 Fires, 2 Smokes, 105.4ms
# Speed: 1.4ms preprocess, 105.4ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 fire, 174.5ms
# Speed: 1.4ms preprocess, 174.5ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 1 Fire, 85.5ms
# Speed: 1.3ms preprocess, 85.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 163.4ms
# Speed: 1.4ms preprocess, 163.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Fire, 1 Smoke, 92.6ms
# Speed: 1.3ms preprocess, 92.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 1 smoke, 163.8ms
# Speed: 1.3ms preprocess, 163.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 Smoke, 98.0ms
# Speed: 1.6ms preprocess, 98.0ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 fire, 1 smoke, 213.7ms
# Speed: 1.5ms preprocess, 213.7ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 Fires, 1 Smoke, 97.2ms
# Speed: 1.4ms preprocess, 97.2ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 fire, 183.2ms
# Speed: 1.5ms preprocess, 183.2ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 Fire, 92.9ms
# Speed: 1.3ms preprocess, 92.9ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 fires, 183.7ms
# Speed: 1.5ms preprocess, 183.7ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 352x640 1 Fire, 86.7ms
# Speed: 1.6ms preprocess, 86.7ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 fire, 146.0ms
# Speed: 1.5ms preprocess, 146.0ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 448x640 1 Smoke, 87.9ms
# Speed: 1.4ms preprocess, 87.9ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 smokes, 182.9ms
# Speed: 1.4ms preprocess, 182.9ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 98.7ms
# Speed: 1.4ms preprocess, 98.7ms inference, 0.3ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 fire, 219.0ms
# Speed: 1.3ms preprocess, 219.0ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 320x640 (no detections), 94.2ms
# Speed: 2.0ms preprocess, 94.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 534.2ms
# Speed: 1.6ms preprocess, 534.2ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 416x640 1 Fire, 110.7ms
# Speed: 1.5ms preprocess, 110.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 fire, 172.9ms
# Speed: 1.5ms preprocess, 172.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 480x640 1 Fire, 102.3ms
# Speed: 1.7ms preprocess, 102.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fire, 241.1ms
# Speed: 1.6ms preprocess, 241.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 Fire, 86.8ms
# Speed: 1.4ms preprocess, 86.8ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 202.2ms
# Speed: 1.4ms preprocess, 202.2ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 Fire, 1 Smoke, 72.9ms
# Speed: 1.5ms preprocess, 72.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 181.8ms
# Speed: 1.3ms preprocess, 181.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x512 2 Fires, 125.6ms
# Speed: 1.7ms preprocess, 125.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 fires, 278.2ms
# Speed: 1.6ms preprocess, 278.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 416x640 1 Smoke, 96.7ms
# Speed: 1.4ms preprocess, 96.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 smokes, 193.3ms
# Speed: 1.6ms preprocess, 193.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 352x640 2 Fires, 66.9ms
# Speed: 1.2ms preprocess, 66.9ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 fires, 148.0ms
# Speed: 1.3ms preprocess, 148.0ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 448x640 1 Smoke, 107.9ms
# Speed: 1.4ms preprocess, 107.9ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 smokes, 192.7ms
# Speed: 2.0ms preprocess, 192.7ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 2 Fires, 78.8ms
# Speed: 1.2ms preprocess, 78.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 175.2ms
# Speed: 1.2ms preprocess, 175.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 4 Fires, 2 Smokes, 92.5ms
# Speed: 1.5ms preprocess, 92.5ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 fires, 208.8ms
# Speed: 1.3ms preprocess, 208.8ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 (no detections), 99.8ms
# Speed: 1.5ms preprocess, 99.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 fires, 281.5ms
# Speed: 1.7ms preprocess, 281.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Fire, 96.2ms
# Speed: 1.6ms preprocess, 96.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 fires, 225.9ms
# Speed: 1.4ms preprocess, 225.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Fires, 114.3ms
# Speed: 1.5ms preprocess, 114.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fire, 264.6ms
# Speed: 1.9ms preprocess, 264.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 Fire, 1 Smoke, 80.2ms
# Speed: 1.3ms preprocess, 80.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fires, 185.1ms
# Speed: 1.4ms preprocess, 185.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 (no detections), 102.8ms
# Speed: 1.7ms preprocess, 102.8ms inference, 0.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 fires, 194.0ms
# Speed: 1.6ms preprocess, 194.0ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 352x640 1 Smoke, 80.0ms
# Speed: 1.3ms preprocess, 80.0ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 smoke, 158.0ms
# Speed: 1.5ms preprocess, 158.0ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 448x640 1 Fire, 3 Smokes, 97.0ms
# Speed: 1.4ms preprocess, 97.0ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 fires, 3 smokes, 204.2ms
# Speed: 1.8ms preprocess, 204.2ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 Fire, 92.7ms
# Speed: 1.4ms preprocess, 92.7ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 3 fires, 203.1ms
# Speed: 1.5ms preprocess, 203.1ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 (no detections), 80.5ms
# Speed: 1.3ms preprocess, 80.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 171.7ms
# Speed: 1.4ms preprocess, 171.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 Fire, 80.1ms
# Speed: 1.3ms preprocess, 80.1ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 fire, 165.7ms
# Speed: 1.4ms preprocess, 165.7ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 Fire, 73.2ms
# Speed: 1.3ms preprocess, 73.2ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 194.2ms
# Speed: 1.1ms preprocess, 194.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 384x640 1 Fire, 1 Smoke, 86.1ms
# Speed: 1.4ms preprocess, 86.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 221.7ms
# Speed: 1.2ms preprocess, 221.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 2 Fires, 88.4ms
# Speed: 1.3ms preprocess, 88.4ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 (no detections), 211.5ms
# Speed: 1.4ms preprocess, 211.5ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 4 Fires, 1 Smoke, 94.2ms
# Speed: 1.6ms preprocess, 94.2ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 fire, 202.7ms
# Speed: 1.4ms preprocess, 202.7ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 352x640 1 Fire, 88.5ms
# Speed: 1.2ms preprocess, 88.5ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 fire, 266.9ms
# Speed: 1.3ms preprocess, 266.9ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 384x640 1 Fire, 77.7ms
# Speed: 1.2ms preprocess, 77.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 177.6ms
# Speed: 1.5ms preprocess, 177.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 Fire, 96.4ms
# Speed: 1.4ms preprocess, 96.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 fire, 240.0ms
# Speed: 1.6ms preprocess, 240.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 2 Fires, 101.5ms
# Speed: 1.5ms preprocess, 101.5ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 2 fires, 199.7ms
# Speed: 1.7ms preprocess, 199.7ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 544x640 (no detections), 131.1ms
# Speed: 1.6ms preprocess, 131.1ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 2 fires, 247.7ms
# Speed: 1.8ms preprocess, 247.7ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 2 Fires, 87.6ms
# Speed: 1.4ms preprocess, 87.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 195.7ms
# Speed: 4.1ms preprocess, 195.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Fires, 89.5ms
# Speed: 1.2ms preprocess, 89.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 177.8ms
# Speed: 1.5ms preprocess, 177.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# # Show video during predicting

# %%
model = YOLO(model_path1)
res = model.predict(input_, show=True, save=True, conf=0.2)
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 160.4ms
# video 1/1 (2/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 88.9ms
# video 1/1 (3/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 81.4ms
# video 1/1 (4/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 80.5ms
# video 1/1 (5/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 82.6ms
# video 1/1 (6/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 85.7ms
# video 1/1 (7/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 78.0ms
# video 1/1 (8/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 77.3ms
# video 1/1 (9/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 80.6ms
# video 1/1 (10/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 82.5ms
# video 1/1 (11/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 85.6ms
# video 1/1 (12/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 77.2ms
# video 1/1 (13/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 74.3ms
# video 1/1 (14/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 76.1ms
# video 1/1 (15/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 80.1ms
# video 1/1 (16/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 79.9ms
# video 1/1 (17/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 77.1ms
# video 1/1 (18/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 79.7ms
# video 1/1 (19/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 81.9ms
# video 1/1 (20/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 76.9ms
# video 1/1 (21/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 79.3ms
# video 1/1 (22/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 74.6ms
# video 1/1 (23/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 78.7ms
# video 1/1 (24/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 78.0ms
# video 1/1 (25/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 77.6ms
# video 1/1 (26/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 76.6ms
# video 1/1 (27/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 81.0ms
# video 1/1 (28/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 79.6ms
# video 1/1 (29/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 84.6ms
# video 1/1 (30/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 78.1ms
# video 1/1 (31/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 80.4ms
# video 1/1 (32/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 77.4ms
# video 1/1 (33/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 76.6ms
# video 1/1 (34/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 78.6ms
# video 1/1 (35/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 74.7ms
# video 1/1 (36/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 83.9ms
# video 1/1 (37/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 76.9ms
# video 1/1 (38/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 81.0ms
# video 1/1 (39/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 76.4ms
# video 1/1 (40/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 78.3ms
# video 1/1 (41/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 1 Fire, 78.2ms
# video 1/1 (42/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 76.4ms
# video 1/1 (43/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 87.0ms
# video 1/1 (44/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 73.7ms
# video 1/1 (45/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 74.1ms
# video 1/1 (46/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 77.8ms
# video 1/1 (47/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 79.6ms
# video 1/1 (48/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 82.8ms
# video 1/1 (49/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 81.5ms
# video 1/1 (50/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 81.2ms
# video 1/1 (51/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 85.7ms
# video 1/1 (52/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 87.0ms
# video 1/1 (53/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 84.0ms
# video 1/1 (54/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 80.1ms
# video 1/1 (55/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 80.9ms
# video 1/1 (56/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 84.9ms
# video 1/1 (57/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 82.9ms
# video 1/1 (58/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 79.7ms
# video 1/1 (59/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 80.4ms
# video 1/1 (60/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 83.2ms
# video 1/1 (61/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 77.6ms
# video 1/1 (62/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 77.7ms
# video 1/1 (63/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 77.2ms
# video 1/1 (64/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 87.2ms
# video 1/1 (65/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 75.9ms
# video 1/1 (66/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 77.8ms
# video 1/1 (67/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 77.0ms
# video 1/1 (68/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 1 Smoke, 81.5ms
# video 1/1 (69/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 1 Smoke, 85.5ms
# video 1/1 (70/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 1 Smoke, 77.2ms
# video 1/1 (71/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 1 Smoke, 77.3ms
# video 1/1 (72/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 1 Smoke, 79.7ms
# video 1/1 (73/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 1 Smoke, 79.9ms
# video 1/1 (74/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 1 Smoke, 79.8ms
# video 1/1 (75/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 1 Smoke, 77.0ms
# video 1/1 (76/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 1 Smoke, 77.1ms
# video 1/1 (77/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 1 Smoke, 77.8ms
# video 1/1 (78/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 77.9ms
# video 1/1 (79/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 76.3ms
# video 1/1 (80/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 81.6ms
# video 1/1 (81/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 85.7ms
# video 1/1 (82/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 1 Smoke, 78.7ms
# video 1/1 (83/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 76.4ms
# video 1/1 (84/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 125.7ms
# video 1/1 (85/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 78.2ms
# video 1/1 (86/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 74.1ms
# video 1/1 (87/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 78.2ms
# video 1/1 (88/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 79.8ms
# video 1/1 (89/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 77.5ms
# video 1/1 (90/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 78.8ms
# video 1/1 (91/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 87.0ms
# video 1/1 (92/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 83.4ms
# video 1/1 (93/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 80.1ms
# video 1/1 (94/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 78.3ms
# video 1/1 (95/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 80.7ms
# video 1/1 (96/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 82.9ms
# video 1/1 (97/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 1 Smoke, 78.4ms
# video 1/1 (98/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 81.0ms
# video 1/1 (99/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 81.7ms
# video 1/1 (100/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 81.3ms
# video 1/1 (101/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 76.6ms
# video 1/1 (102/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 1 Smoke, 77.5ms
# video 1/1 (103/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 77.4ms
# video 1/1 (104/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 79.4ms
# video 1/1 (105/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 1 Smoke, 76.6ms
# video 1/1 (106/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 77.0ms
# video 1/1 (107/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 78.3ms
# video 1/1 (108/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 1 Smoke, 134.5ms
# video 1/1 (109/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 83.2ms
# video 1/1 (110/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 85.2ms
# video 1/1 (111/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 80.8ms
# video 1/1 (112/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 1 Smoke, 87.4ms
# video 1/1 (113/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 1 Smoke, 83.8ms
# video 1/1 (114/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 78.6ms
# video 1/1 (115/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 78.5ms
# video 1/1 (116/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 80.6ms
# video 1/1 (117/2920) /Users/lefterisfthenos/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/test_files/rodos_maris.mp4: 384x640 (no detections), 78.1ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 model = YOLO(model_path1)
# ----> 2 res = model.predict(input_, show=True, save=True, conf=0.2)
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/ultralytics/engine/model.py:246, in Model.predict(self, source, stream, predictor, **kwargs)
#     244 if len and hasattr(self.predictor, 'set_prompts'):
#     245     self.predictor.set_prompts(prompts)
# --> 246 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/ultralytics/engine/predictor.py:197, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     195     return self.stream_inference(source, model, *args, **kwargs)
#     196 else:
# --> 197     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/torch/utils/_contextlib.py:56, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      53         else:
#      54             # Pass the last request to the generator and get its response
#      55             with ctx_factory():
# ---> 56                 response = gen.send(request)
#      58 # We let the exceptions raised above by the generator's `.throw` or
#      59 # `.send` methods bubble up to our caller, except for StopIteration
#      60 except StopIteration as e:
#      61     # The generator informed us that it is done: take whatever its
#      62     # returned value (if any) was and indicate that we're done too
#      63     # by returning it (see docs for python's return-statement).
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/ultralytics/engine/predictor.py:253, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     251 # Inference
#     252 with profilers[1]:
# --> 253     preds = self.inference(im, *args, **kwargs)
#     255 # Postprocess
#     256 with profilers[2]:
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/ultralytics/engine/predictor.py:138, in BasePredictor.inference(self, im, *args, **kwargs)
#     135 def inference(self, im, *args, **kwargs):
#     136     visualize = increment_path(self.save_dir / Path(self.batch[0][0]).stem,
#     137                                mkdir=True) if self.args.visualize and (not self.source_type.tensor) else False
# --> 138     return self.model(im, augment=self.args.augment, visualize=visualize)
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/ultralytics/nn/autobackend.py:334, in AutoBackend.forward(self, im, augment, visualize)
#     331     im = im.permute(0, 2, 3, 1)  # torch BCHW to numpy BHWC shape(1,320,192,3)
#     333 if self.pt or self.nn_module:  # PyTorch
# --> 334     y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     335 elif self.jit:  # TorchScript
#     336     y = self.model(im)
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/ultralytics/nn/tasks.py:45, in BaseModel.forward(self, x, *args, **kwargs)
#      43 if isinstance(x, dict):  # for cases of training and validating while training.
#      44     return self.loss(x, *args, **kwargs)
# ---> 45 return self.predict(x, *args, **kwargs)
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/ultralytics/nn/tasks.py:62, in BaseModel.predict(self, x, profile, visualize, augment)
#      60 if augment:
#      61     return self._predict_augment(x)
# ---> 62 return self._predict_once(x, profile, visualize)
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/ultralytics/nn/tasks.py:82, in BaseModel._predict_once(self, x, profile, visualize)
#      80 if profile:
#      81     self._profile_one_layer(m, x, dt)
# ---> 82 x = m(x)  # run
#      83 y.append(x if m.i in self.save else None)  # save output
#      84 if visualize:
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/ultralytics/nn/modules/block.py:134, in SPPF.forward(self, x)
#     132 y1 = self.m(x)
#     133 y2 = self.m(y1)
# --> 134 return self.cv2(torch.cat((x, y1, y2, self.m(y2)), 1))
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/ultralytics/nn/modules/conv.py:42, in Conv.forward_fuse(self, x)
#      40 def forward_fuse(self, x):
#      41     """Perform transposed convolution of 2D data."""
# ---> 42     return self.act(self.conv(x))
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:463, in Conv2d.forward(self, input)
#     462 def forward(self, input: Tensor) -> Tensor:
# --> 463     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:459, in Conv2d._conv_forward(self, input, weight, bias)
#     455 if self.padding_mode != 'zeros':
#     456     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                     weight, bias, self.stride,
#     458                     _pair(0), self.dilation, self.groups)
# --> 459 return F.conv2d(input, weight, bias, self.stride,
#     460                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %% [markdown]
# # Live Webcam Video Predicting and make sound if conf > 0.2

# %%
import cv2
import beepy as beep


def draw_boxes(annotator, results, model, color):
        for r in results:
            boxes = r.boxes
            for box in boxes:
                b = box.xyxy[0]  # get box coordinates in (top, left, bottom, right) format
                c = box.cls
                conf = box.conf.item()
                if conf > 0.2:
                    beep.beep(3)
                label = f"{model.names[int(c)]} {box.conf.item():.2f}"  # Add confidence to the label
                annotator.box_label(b, label, color=color)
                

def capture_webcam_video(model):
    color_model1 = (0, 255, 0)
    # Open the default camera (usually the built-in webcam)
    cap = cv2.VideoCapture(0)

    # Check if the camera opened successfully
    if not cap.isOpened():
        print("Error: Could not open camera.")
        return

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()

        # If frame is read correctly, ret is True
        if not ret:
            print("Error: Can't receive frame. Exiting ...")
            break

        # Display the resulting frame
        img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Predict with both models
        results1 = model.predict(img, conf=0.2)
        annotator = Annotator(frame)

        draw_boxes(annotator, results1, model, color_model1)

        frame = annotator.result()

        # write the flipped frame
        cv2.imshow('Webcam Video', frame)

        # Press 'q' to exit the video window
        if cv2.waitKey(1) == ord('q'):
            break

    # Release the capture when everything is done
    cap.release()
    cv2.destroyAllWindows()

# %%
capture_webcam_video(model=YOLO(model_path2))
# Out:
# 0: 384x640 (no detections), 176.6ms
# Speed: 1.7ms preprocess, 176.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 171.4ms
# Speed: 1.5ms preprocess, 171.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 166.3ms
# Speed: 1.4ms preprocess, 166.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 158.0ms
# Speed: 1.3ms preprocess, 158.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 156.4ms
# Speed: 1.4ms preprocess, 156.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 154.5ms
# Speed: 1.4ms preprocess, 154.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 158.5ms
# Speed: 1.5ms preprocess, 158.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 smoke, 156.3ms
# Speed: 1.5ms preprocess, 156.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 163.7ms
# Speed: 2.8ms preprocess, 163.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 smoke, 156.0ms
# Speed: 1.4ms preprocess, 156.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 168.7ms
# Speed: 3.0ms preprocess, 168.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 157.8ms
# Speed: 1.3ms preprocess, 157.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 157.1ms
# Speed: 1.3ms preprocess, 157.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 159.3ms
# Speed: 1.2ms preprocess, 159.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 159.4ms
# Speed: 1.3ms preprocess, 159.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 159.6ms
# Speed: 1.3ms preprocess, 159.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 155.2ms
# Speed: 1.3ms preprocess, 155.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 159.7ms
# Speed: 1.3ms preprocess, 159.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 smoke, 158.5ms
# Speed: 1.3ms preprocess, 158.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 173.7ms
# Speed: 3.3ms preprocess, 173.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 158.0ms
# Speed: 1.3ms preprocess, 158.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 158.6ms
# Speed: 1.4ms preprocess, 158.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 157.8ms
# Speed: 1.3ms preprocess, 157.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 156.4ms
# Speed: 1.4ms preprocess, 156.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 159.5ms
# Speed: 1.4ms preprocess, 159.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 158.0ms
# Speed: 1.3ms preprocess, 158.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 173.6ms
# Speed: 3.3ms preprocess, 173.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 172.5ms
# Speed: 3.2ms preprocess, 172.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 156.7ms
# Speed: 1.3ms preprocess, 156.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 157.1ms
# Speed: 1.7ms preprocess, 157.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 171.6ms
# Speed: 3.4ms preprocess, 171.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 160.9ms
# Speed: 1.4ms preprocess, 160.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 166.6ms
# Speed: 1.3ms preprocess, 166.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 157.4ms
# Speed: 1.3ms preprocess, 157.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 167.7ms
# Speed: 3.5ms preprocess, 167.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 173.0ms
# Speed: 3.2ms preprocess, 173.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 174.2ms
# Speed: 3.5ms preprocess, 174.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 174.2ms
# Speed: 3.7ms preprocess, 174.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 176.7ms
# Speed: 3.2ms preprocess, 176.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 173.4ms
# Speed: 3.6ms preprocess, 173.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 172.1ms
# Speed: 3.2ms preprocess, 172.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 177.5ms
# Speed: 3.4ms preprocess, 177.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 172.8ms
# Speed: 3.2ms preprocess, 172.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 161.9ms
# Speed: 1.3ms preprocess, 161.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 158.1ms
# Speed: 1.4ms preprocess, 158.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 157.9ms
# Speed: 1.3ms preprocess, 157.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 156.0ms
# Speed: 1.3ms preprocess, 156.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 159.9ms
# Speed: 1.4ms preprocess, 159.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 174.2ms
# Speed: 3.4ms preprocess, 174.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 158.8ms
# Speed: 1.3ms preprocess, 158.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 158.3ms
# Speed: 1.4ms preprocess, 158.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 175.0ms
# Speed: 3.1ms preprocess, 175.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 173.4ms
# Speed: 3.4ms preprocess, 173.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 172.1ms
# Speed: 3.3ms preprocess, 172.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 160.3ms
# Speed: 1.3ms preprocess, 160.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 157.4ms
# Speed: 1.3ms preprocess, 157.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 158.7ms
# Speed: 1.4ms preprocess, 158.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 159.9ms
# Speed: 1.3ms preprocess, 159.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 157.6ms
# Speed: 1.3ms preprocess, 157.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 222.3ms
# Speed: 1.7ms preprocess, 222.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 167.9ms
# Speed: 1.3ms preprocess, 167.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 165.8ms
# Speed: 1.2ms preprocess, 165.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 164.1ms
# Speed: 1.3ms preprocess, 164.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 161.8ms
# Speed: 1.4ms preprocess, 161.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 160.5ms
# Speed: 1.3ms preprocess, 160.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 capture_webcam_video(model=YOLO(model_path2))
#
# Cell In[14], line 39, in capture_webcam_video(model)
#      36 img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#      38 # Predict with both models
# ---> 39 results1 = model.predict(img, conf=0.2)
#      40 annotator = Annotator(frame)
#      42 draw_boxes(annotator, results1, model, color_model1)
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/ultralytics/engine/model.py:246, in Model.predict(self, source, stream, predictor, **kwargs)
#     244 if len and hasattr(self.predictor, 'set_prompts'):
#     245     self.predictor.set_prompts(prompts)
# --> 246 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/ultralytics/engine/predictor.py:197, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     195     return self.stream_inference(source, model, *args, **kwargs)
#     196 else:
# --> 197     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/torch/utils/_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/ultralytics/engine/predictor.py:253, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     251 # Inference
#     252 with profilers[1]:
# --> 253     preds = self.inference(im, *args, **kwargs)
#     255 # Postprocess
#     256 with profilers[2]:
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/ultralytics/engine/predictor.py:138, in BasePredictor.inference(self, im, *args, **kwargs)
#     135 def inference(self, im, *args, **kwargs):
#     136     visualize = increment_path(self.save_dir / Path(self.batch[0][0]).stem,
#     137                                mkdir=True) if self.args.visualize and (not self.source_type.tensor) else False
# --> 138     return self.model(im, augment=self.args.augment, visualize=visualize)
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/ultralytics/nn/autobackend.py:334, in AutoBackend.forward(self, im, augment, visualize)
#     331     im = im.permute(0, 2, 3, 1)  # torch BCHW to numpy BHWC shape(1,320,192,3)
#     333 if self.pt or self.nn_module:  # PyTorch
# --> 334     y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     335 elif self.jit:  # TorchScript
#     336     y = self.model(im)
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/ultralytics/nn/tasks.py:45, in BaseModel.forward(self, x, *args, **kwargs)
#      43 if isinstance(x, dict):  # for cases of training and validating while training.
#      44     return self.loss(x, *args, **kwargs)
# ---> 45 return self.predict(x, *args, **kwargs)
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/ultralytics/nn/tasks.py:62, in BaseModel.predict(self, x, profile, visualize, augment)
#      60 if augment:
#      61     return self._predict_augment(x)
# ---> 62 return self._predict_once(x, profile, visualize)
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/ultralytics/nn/tasks.py:82, in BaseModel._predict_once(self, x, profile, visualize)
#      80 if profile:
#      81     self._profile_one_layer(m, x, dt)
# ---> 82 x = m(x)  # run
#      83 y.append(x if m.i in self.save else None)  # save output
#      84 if visualize:
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/ultralytics/nn/modules/block.py:180, in C2f.forward(self, x)
#     178 def forward(self, x):
#     179     """Forward pass through C2f layer."""
# --> 180     y = list(self.cv1(x).chunk(2, 1))
#     181     y.extend(m(y[-1]) for m in self.m)
#     182     return self.cv2(torch.cat(y, 1))
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/ultralytics/nn/modules/conv.py:42, in Conv.forward_fuse(self, x)
#      40 def forward_fuse(self, x):
#      41     """Perform transposed convolution of 2D data."""
# ---> 42     return self.act(self.conv(x))
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/torch/nn/modules/activation.py:396, in SiLU.forward(self, input)
#     395 def forward(self, input: Tensor) -> Tensor:
# --> 396     return F.silu(input, inplace=self.inplace)
#
# File ~/Desktop/MSBA - AUEB/Semester 3/Artificial Intelligence/CourseProject/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2058, in silu(input, inplace)
#    2056     return handle_torch_function(silu, (input,), input, inplace=inplace)
#    2057 if inplace:
# -> 2058     return torch._C._nn.silu_(input)
#    2059 return torch._C._nn.silu(input)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
